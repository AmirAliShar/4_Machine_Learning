# %% [markdown]
# **Cross-validation is a technique in machine learning used to assess the generalization ability of a model on an independent dataset. It divides the data into subsets, trains the model on some of these subsets, and tests it on the others, helping to ensure that the model performs well on unseen data.**

# %%
# import the dependancies
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB

# %%
#load the data set
iris=load_iris()
X=iris.data
Y=iris.target

#Defini the Guassian naive model
model=GaussianNB()

#perform the k-fold CV with k=5
score=cross_val_score(model,X,Y,cv=4,scoring='accuracy')

#print the score for each fold and mean score
print("Score  For each fold =",score)
print(" mean =",score.mean())
print('standard deviation =',score.std())
# Out:
# Score  For each fold = [0.94736842 0.94736842 0.91891892 1.        ]
#  mean = 0.9534139402560455
# standard deviation = 0.029297030840999088

# %%
#Plot the cross validation 
#define the decsion tree classifier
clf=DecisionTreeClassifier()

#Perform the CV witn k=8
score=cross_val_score(clf,X,Y,cv=8)
#plot the result 
plt.figure(figsize=(5,4))
#plt.plot(range(1,9),score,color='blue',linestyle='dashed',marker='o',markerfacecolor='red', markersize=12)
plt.plot(range(1,9),score,color='blue',linestyle='dashed',marker='o')
plt.title("K fold CV result")
plt.xlabel("Fold Number")
plt.ylabel("accuracy")
plt.ylim([0.5,1])
plt.show()

# %%
df=sns.load_dataset("tips")
for i in df:
    if df[i].dtype =="category":
        df[i]=LabelEncoder().fit_transform(df[i])
#Seprate the feature and target variable
X=df.drop("tip",axis=1)
Y=df["tip"]

# %%
modelR =RandomForestRegressor()
score=cross_val_score(modelR,X,Y,cv=5,scoring="r2")

print("score ",score)
print("mean ",score.mean())
# Out:
# score  [0.37745071 0.47146756 0.48853983 0.102932   0.33427825]
# mean  0.3549336689617696
